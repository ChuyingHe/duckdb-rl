# %%
import os 
import duckdb_query_graph
import json
import csv
import pandas as pd
from IPython.display import display, HTML
import matplotlib.pyplot as plt

#import duckdb
#cursor = duckdb.connect()
#print(cursor.execute('SELECT 42').fetchall())
cwd = os.getcwd()

# %% [markdown]
# # DuckDB query graph

# %%
profiling_dir = cwd+"/profiling"
print(profiling_dir)
# Out:
# /Users/chuyinghe/CLionProjects/duckdb-rl-back-up-visualization/query-graph/profiling

# %%
# %cd profiling
# %ls
# Out:
# /Users/chuyinghe/CLionProjects/duckdb-rl-back-up-visualization/query-graph/profiling
# 10a.sql.json  16c.sql.json  21b.sql.json  29a.sql.json  4c.sql.json
# 10b.sql.json  16d.sql.json  21c.sql.json  29b.sql.json  5a.sql.json
# 10c.sql.json  17a.sql.json  22a.sql.json  29c.sql.json  5b.sql.json
# 11a.sql.json  17b.sql.json  22b.sql.json  2a.sql.json   5c.sql.json
# 11b.sql.json  17c.sql.json  22c.sql.json  2b.sql.json   6a.sql.json
# 11c.sql.json  17d.sql.json  22d.sql.json  2c.sql.json   6b.sql.json
# 11d.sql.json  17e.sql.json  23a.sql.json  2d.sql.json   6c.sql.json
# 12a.sql.json  17f.sql.json  23b.sql.json  30a.sql.json  6d.sql.json
# 12b.sql.json  18a.sql.json  23c.sql.json  30b.sql.json  6e.sql.json
# 12c.sql.json  18b.sql.json  24a.sql.json  30c.sql.json  6f.sql.json
# 13a.sql.json  18c.sql.json  24b.sql.json  31a.sql.json  7a.sql.json
# 13b.sql.json  19a.sql.json  25a.sql.json  31b.sql.json  7b.sql.json
# 13c.sql.json  19b.sql.json  25b.sql.json  31c.sql.json  7c.sql.json
# 13d.sql.json  19c.sql.json  25c.sql.json  32a.sql.json  8a.sql.json
# 14a.sql.json  19d.sql.json  26a.sql.json  32b.sql.json  8b.sql.json
# 14b.sql.json  1a.sql.json   26b.sql.json  33a.sql.json  8c.sql.json
# 14c.sql.json  1b.sql.json   26c.sql.json  33b.sql.json  8d.sql.json
# 15a.sql.json  1c.sql.json   27a.sql.json  33c.sql.json  9a.sql.json
# 15b.sql.json  1d.sql.json   27b.sql.json  3a.sql.json   9b.sql.json
# 15c.sql.json  20a.sql.json  27c.sql.json  3b.sql.json   9c.sql.json
# 15d.sql.json  20b.sql.json  28a.sql.json  3c.sql.json   9d.sql.json
# 16a.sql.json  20c.sql.json  28b.sql.json  4a.sql.json
# 16b.sql.json  21a.sql.json  28c.sql.json  4b.sql.json

# %%
counter = 0
for json_filename in os.listdir(profiling_dir):
    if(json_filename != ".DS_Store"):
        counter+=1
        html_filename = json_filename +'.html'
        json_dir = profiling_dir +"/"+ json_filename
        html_dir = profiling_dir +"/"+ html_filename

        print(json_dir, " --> ", html_dir)
        test = duckdb_query_graph.generate(json_dir, html_dir)
    
print("🧽🧽🧽🧽🧽🧽🧽🧽🧽🧽🧽🧽counter = ", counter)
# Out:
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/17c.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/17c.sql.json.html
# <script>
# var graph_json = '{    "result": 1.885597,    "timings": {       "optimizer": 0.007862,       "optimizer > column_lifetime": 0.000018,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000137,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000192,       "optimizer > in_clause": 0.000001,       "optimizer > join_order": 0.007446,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000027,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000012,       "physical_planner": 0.000063,       "physical_planner > column_binding": 0.000020,       "physical_planner > create_plan": 0.000027,       "physical_planner > resolve_types": 0.000007,       "planner": 0.000189,       "planner > binder": 0.000183    },    "tree": {    "name": "PROJECTION",    "timing":0.00,    "cardinality":1,    "extra_info": "member_in_charnamed_movie\\na1\\n",    "children": [    {       "name": "SIMPLE_AGGREGATE",       "timing":0.00,       "cardinality":1,       "extra_info": "min(#0)",       "children": [       {          "name": "PROJECTION",          "timing":0.00,          "cardinality":1918,          "extra_info": "name\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":1918,             "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.14,                "cardinality":12500,                "extra_info": "INNER\\nperson_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.04,                   "cardinality":36244344,                   "extra_info": "cast_info\\n[INFOSEPARATOR]\\nperson_id\\nmovie_id",                   "children": []                   },                {                   "name": "FILTER",                   "timing":0.00,                   "cardinality":2664,                   "extra_info": "prefix(name, X)",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.06,                      "cardinality":2664,                      "extra_info": "name\\n[INFOSEPARATOR]\\nname\\nid\\n[INFOSEPARATOR]\\nFilters: \\nname>=X\\nname<Y",                      "children": []                      }                   ]                   }                ]                },             {                "name": "HASH_JOIN",                "timing":0.01,                "cardinality":148552,                "extra_info": "INNER\\ncompany_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.53,                   "cardinality":148552,                   "extra_info": "INNER\\nkeyword_id=id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.75,                      "cardinality":34863638,                      "extra_info": "INNER\\nid=movie_id\\nmovie_id=movie_id\\n",                      "children": [                      {                         "name": "HASH_JOIN",                         "timing":0.10,                         "cardinality":4523930,                         "extra_info": "INNER\\nmovie_id=id\\n",                         "children": [                         {                            "name": "SEQ_SCAN",                            "timing":0.01,                            "cardinality":4523930,                            "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                            "children": []                            },             ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/17b.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/17b.sql.json.html
# <script>
# var graph_json = '{    "result": 1.995868,    "timings": {       "optimizer": 0.014394,       "optimizer > column_lifetime": 0.000025,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000003,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000265,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000373,       "optimizer > in_clause": 0.000002,       "optimizer > join_order": 0.013636,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000006,       "optimizer > statistics_propagation": 0.000031,       "optimizer > top_n": 0.000000,       "optimizer > unused_columns": 0.000016,       "physical_planner": 0.000094,       "physical_planner > column_binding": 0.000030,       "physical_planner > create_plan": 0.000043,       "physical_planner > resolve_types": 0.000008,       "planner": 0.000359,       "planner > binder": 0.000349    },    "tree": {    "name": "PROJECTION",    "timing":0.00,    "cardinality":1,    "extra_info": "member_in_charnamed_movie\\na1\\n",    "children": [    {       "name": "SIMPLE_AGGREGATE",       "timing":0.00,       "cardinality":1,       "extra_info": "min(#0)",       "children": [       {          "name": "PROJECTION",          "timing":0.00,          "cardinality":52306,          "extra_info": "name\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.05,             "cardinality":52306,             "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.17,                "cardinality":268710,                "extra_info": "INNER\\nperson_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.04,                   "cardinality":36244344,                   "extra_info": "cast_info\\n[INFOSEPARATOR]\\nperson_id\\nmovie_id",                   "children": []                   },                {                   "name": "FILTER",                   "timing":0.00,                   "cardinality":36174,                   "extra_info": "prefix(name, Z)",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.06,                      "cardinality":36174,                      "extra_info": "name\\n[INFOSEPARATOR]\\nname\\nid\\n[INFOSEPARATOR]\\nFilters: \\nname>=Z\\nname<[",                      "children": []                      }                   ]                   }                ]                },             {                "name": "HASH_JOIN",                "timing":0.01,                "cardinality":148552,                "extra_info": "INNER\\ncompany_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.53,                   "cardinality":148552,                   "extra_info": "INNER\\nkeyword_id=id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.76,                      "cardinality":34863638,                      "extra_info": "INNER\\nid=movie_id\\nmovie_id=movie_id\\n",                      "children": [                      {                         "name": "HASH_JOIN",                         "timing":0.11,                         "cardinality":4523930,                         "extra_info": "INNER\\nmovie_id=id\\n",                         "children": [                         {                            "name": "SEQ_SCAN",                            "timing":0.01,                            "cardinality":4523930,                            "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                            "children": []                            },        ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/6f.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/6f.sql.json.html
# <script>
# var graph_json = '{    "result": 3.195914,    "timings": {       "optimizer": 0.001045,       "optimizer > column_lifetime": 0.000021,       "optimizer > common_aggregate": 0.000003,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000000,       "optimizer > expression_rewriter": 0.000028,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000141,       "optimizer > in_clause": 0.000046,       "optimizer > join_order": 0.000741,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000022,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000013,       "physical_planner": 0.000064,       "physical_planner > column_binding": 0.000019,       "physical_planner > create_plan": 0.000026,       "physical_planner > resolve_types": 0.000008,       "planner": 0.000173,       "planner > binder": 0.000166    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.02,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":785477,       "extra_info": "keyword\\nname\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":1.93,          "cardinality":785477,          "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.71,             "cardinality":36244344,             "extra_info": "INNER\\nperson_id=id\\n",             "children": [             {                "name": "SEQ_SCAN",                "timing":0.05,                "cardinality":36244344,                "extra_info": "cast_info\\n[INFOSEPARATOR]\\nmovie_id\\nperson_id",                "children": []                },             {                "name": "SEQ_SCAN",                "timing":0.04,                "cardinality":4167491,                "extra_info": "name\\n[INFOSEPARATOR]\\nname\\nid",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.02,             "cardinality":14165,             "extra_info": "INNER\\nkeyword_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.10,                "cardinality":1970380,                "extra_info": "INNER\\nmovie_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":4523930,                   "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nkeyword_id\\nmovie_id",                   "children": []                   },                {                   "name": "SEQ_SCAN",                   "timing":0.03,                   "cardinality":1381453,                   "extra_info": "title\\n[INFOSEPARATOR]\\ntitle\\nproduction_year\\nid\\n[INFOSEPARATOR]\\nFilters: \\nproduction_year>2000",                   "children": []                   }                ]                },             {                "name": "PROJECTION",                "timing":0.00,                "cardinality":8,                "extra_info": "#0\\n#1\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.00,                   "cardinality":8,                   "extra_info": "IN (...)",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.01,                      "cardinality":119352,                      "extra_info": "MARK\\nkeyword=#0\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":0.02,                         "cardinality":119352,                         "extra_info": "keyw ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/22c.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/22c.sql.json.html
# <script>
# var graph_json = '{    "result": 2.609435,    "timings": {       "optimizer": 0.010276,       "optimizer > column_lifetime": 0.000075,       "optimizer > common_aggregate": 0.000004,       "optimizer > common_subexpressions": 0.000004,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000151,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000410,       "optimizer > in_clause": 0.000049,       "optimizer > join_order": 0.009458,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000008,       "optimizer > statistics_propagation": 0.000053,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000043,       "physical_planner": 0.000130,       "physical_planner > column_binding": 0.000050,       "physical_planner > create_plan": 0.000048,       "physical_planner > resolve_types": 0.000015,       "planner": 0.000236,       "planner > binder": 0.000230    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":21489,       "extra_info": "name\\ninfo\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.11,          "cardinality":21489,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":614251,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "PROJECTION",                "timing":0.00,                "cardinality":716210,                "extra_info": "#1\\n#2\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.02,                   "cardinality":716210,                   "extra_info": "IN (...)",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.58,                      "cardinality":11827587,                      "extra_info": "MARK\\ninfo=#0\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":1.45,                         "cardinality":11827587,                         "extra_info": "movie_info\\n[INFOSEPARATOR]\\ninfo\\nmovie_id\\ninfo_type_id\\n[INFOSEPARATOR]\\nFilters: \\ninfo>=American\\ninfo<=USA",                         "children": []                         },                      {                         "name": "CHUNK_SCAN",                         "timing":0.00,                         "cardinality":10,                         "extra_info": "",                         "children": []                         }                      ]                      }                   ]                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=countries",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":23425,             "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.03,                "cardinality":37091,                "extra_info": "INNER\\nkeyword_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":4523930,                   "extra_info": "movie_keyword\\n[INFOSEPARA ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/22b.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/22b.sql.json.html
# <script>
# var graph_json = '{    "result": 2.089543,    "timings": {       "optimizer": 0.009369,       "optimizer > column_lifetime": 0.000063,       "optimizer > common_aggregate": 0.000005,       "optimizer > common_subexpressions": 0.000004,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000151,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000403,       "optimizer > in_clause": 0.000006,       "optimizer > join_order": 0.008638,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000009,       "optimizer > statistics_propagation": 0.000045,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000022,       "physical_planner": 0.000115,       "physical_planner > column_binding": 0.000045,       "physical_planner > create_plan": 0.000043,       "physical_planner > resolve_types": 0.000012,       "planner": 0.000249,       "planner > binder": 0.000241    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":31,       "extra_info": "name\\ninfo\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.01,          "cardinality":31,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":588764,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "PROJECTION",                "timing":0.00,                "cardinality":669336,                "extra_info": "#1\\n#2\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.29,                   "cardinality":669336,                   "extra_info": "(info=Germany OR info=German OR info=USA OR info=American)",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":1.45,                      "cardinality":11827587,                      "extra_info": "movie_info\\n[INFOSEPARATOR]\\ninfo\\nmovie_id\\ninfo_type_id\\n[INFOSEPARATOR]\\nFilters: \\ninfo>=American\\ninfo<=USA",                      "children": []                      }                   ]                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=countries",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":50,             "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.03,                "cardinality":37091,                "extra_info": "INNER\\nkeyword_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":4523930,                   "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                   "children": []                   },                {                   "name": "PROJECTION",                   "timing":0.00,                   "cardinality":3,                   "extra_info": "#1\\n",                   "children": [                   {                      "name": "FILTER",                      "timing":0.00,                      "cardinality":3,                      "extra_info": "(keyword=murder OR keyword=murder-in-title OR keyword=blood OR key ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/8b.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/8b.sql.json.html
# <script>
# var graph_json = '{    "result": 1.996053,    "timings": {       "optimizer": 0.008379,       "optimizer > column_lifetime": 0.000019,       "optimizer > common_aggregate": 0.000003,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000000,       "optimizer > expression_rewriter": 0.000591,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000279,       "optimizer > in_clause": 0.000002,       "optimizer > join_order": 0.007412,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000007,       "optimizer > statistics_propagation": 0.000032,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000013,       "physical_planner": 0.000778,       "physical_planner > column_binding": 0.000028,       "physical_planner > create_plan": 0.000049,       "physical_planner > resolve_types": 0.000689,       "planner": 0.000232,       "planner > binder": 0.000225    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":6,       "extra_info": "name\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.04,          "cardinality":6,          "extra_info": "INNER\\nid=person_id\\nperson_id=person_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":4,             "extra_info": "INNER\\nmovie_id=id\\nmovie_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.00,                "cardinality":16,                "extra_info": "INNER\\nrole_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.00,                   "cardinality":42,                   "extra_info": "INNER\\nmovie_id=movie_id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.02,                      "cardinality":938,                      "extra_info": "INNER\\nperson_id=id\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":1.49,                         "cardinality":93095,                         "extra_info": "cast_info\\n[INFOSEPARATOR]\\nnote\\nperson_id\\nmovie_id\\nrole_id\\n[INFOSEPARATOR]\\nFilters: \\nnote=(voice: English version)",                         "children": []                         },                      {                         "name": "PROJECTION",                         "timing":0.00,                         "cardinality":20911,                         "extra_info": "#1\\n",                         "children": [                         {                            "name": "FILTER",                            "timing":0.09,                            "cardinality":20911,                            "extra_info": "(!~~(name, %Yu%) AND contains(name, Yo))",                            "children": [                            {                               "name": "SEQ_SCAN",                               "timing":0.19,                               "cardinality":4167491,                               "extra_info": "name\\n[INFOSEPARATOR]\\nname\\nid",                               "children": []                               }                            ]                            }                         ]                         }                      ]                      },                   {                      "name": "HASH_JOIN",                      "timing":0.01,                      "cardinality":8495,                      "extra_info": "INNER\\ncompany_id=id\\n",                      "children": [                      {                         "name": "PROJECTION" ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/8c.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/8c.sql.json.html
# <script>
# var graph_json = '{    "result": 7.742933,    "timings": {       "optimizer": 0.007478,       "optimizer > column_lifetime": 0.000013,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000000,       "optimizer > expression_rewriter": 0.000037,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000367,       "optimizer > in_clause": 0.000001,       "optimizer > join_order": 0.006992,       "optimizer > regex_range": 0.000003,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000027,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000012,       "physical_planner": 0.000094,       "physical_planner > column_binding": 0.000028,       "physical_planner > create_plan": 0.000044,       "physical_planner > resolve_types": 0.000009,       "planner": 0.000171,       "planner > binder": 0.000165    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.04,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)",    "children": [    {       "name": "PROJECTION",       "timing":0.02,       "cardinality":2487611,       "extra_info": "name\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":1.08,          "cardinality":2487611,          "extra_info": "INNER\\nid=person_id\\nperson_id=person_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":1.40,             "cardinality":1970658,             "extra_info": "INNER\\nmovie_id=id\\nmovie_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.46,                "cardinality":1970658,                "extra_info": "INNER\\nrole_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":3.34,                   "cardinality":32289229,                   "extra_info": "INNER\\nmovie_id=movie_id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.61,                      "cardinality":36244344,                      "extra_info": "INNER\\nperson_id=id\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":0.30,                         "cardinality":36244344,                         "extra_info": "cast_info\\n[INFOSEPARATOR]\\nperson_id\\nmovie_id\\nrole_id",                         "children": []                         },                      {                         "name": "SEQ_SCAN",                         "timing":0.00,                         "cardinality":4167491,                         "extra_info": "name\\n[INFOSEPARATOR]\\nid",                         "children": []                         }                      ]                      },                   {                      "name": "HASH_JOIN",                      "timing":0.04,                      "cardinality":1153798,                      "extra_info": "INNER\\ncompany_id=id\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":0.00,                         "cardinality":2609129,                         "extra_info": "movie_companies\\n[INFOSEPARATOR]\\nmovie_id\\ncompany_id",                         "children": []                         },                      {                         "name": "SEQ_SCAN",                         "timing":0.01,                         "cardinality":84843,                         "extra_info": "company_name\\n[INFOSEPARATOR]\\ncountry_code\\nid\\n[INFOSEPARATOR]\\nFilters: \\ncountry_code=[us]",                         "children": []                         }                      ]                      }                   ]                   },                {  ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/1a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/1a.sql.json.html
# <script>
# var graph_json = '{    "result": 0.490894,    "timings": {       "optimizer": 0.002596,       "optimizer > column_lifetime": 0.000026,       "optimizer > common_aggregate": 0.000006,       "optimizer > common_subexpressions": 0.000004,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000767,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000406,       "optimizer > in_clause": 0.000004,       "optimizer > join_order": 0.001265,       "optimizer > regex_range": 0.000002,       "optimizer > reorder_filter": 0.000013,       "optimizer > statistics_propagation": 0.000041,       "optimizer > top_n": 0.000000,       "optimizer > unused_columns": 0.000023,       "physical_planner": 0.000107,       "physical_planner > column_binding": 0.000037,       "physical_planner > create_plan": 0.000040,       "physical_planner > resolve_types": 0.000013,       "planner": 0.000406,       "planner > binder": 0.000392    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":142,       "extra_info": "note\\ntitle\\nproduction_year\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.00,          "cardinality":142,          "extra_info": "INNER\\ncompany_type_id=id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":147,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.15,                "cardinality":62658,                "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.11,                   "cardinality":28889,                   "extra_info": "(!~~(note, %(as Metro-Goldwyn-Mayer Pictures)%) AND (contains(note, (co-production)) OR contains(note, (presents))))",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.02,                      "cardinality":2609129,                      "extra_info": "movie_companies\\n[INFOSEPARATOR]\\nnote\\ncompany_type_id\\nmovie_id",                      "children": []                      }                   ]                   },                {                   "name": "HASH_JOIN",                   "timing":0.09,                   "cardinality":1380035,                   "extra_info": "INNER\\nid=movie_id\\n",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.04,                      "cardinality":2528312,                      "extra_info": "title\\n[INFOSEPARATOR]\\ntitle\\nproduction_year\\nid",                      "children": []                      },                   {                      "name": "SEQ_SCAN",                      "timing":0.00,                      "cardinality":1380035,                      "extra_info": "movie_info_idx\\n[INFOSEPARATOR]\\nmovie_id\\ninfo_type_id",                      "children": []                      }                   ]                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=top 250 rank",                "children": []                }             ]             },          {             "name": "SEQ_SCAN",             "timing":0.00,             "cardinality":1,             "extra_info": "company_type\\n[INFOSEPARATOR]\\nkind\\nid\\n[INFOSEPARATOR]\\nFilters: \\nkind=production companies",             "children": []             }          ]  ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/13a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/13a.sql.json.html
# <script>
# var graph_json = '{    "result": 2.407215,    "timings": {       "optimizer": 0.007942,       "optimizer > column_lifetime": 0.000035,       "optimizer > common_aggregate": 0.000004,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000047,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000274,       "optimizer > in_clause": 0.000001,       "optimizer > join_order": 0.007506,       "optimizer > regex_range": 0.000000,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000033,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000018,       "physical_planner": 0.000086,       "physical_planner > column_binding": 0.000029,       "physical_planner > create_plan": 0.000033,       "physical_planner > resolve_types": 0.000011,       "planner": 0.000179,       "planner > binder": 0.000173    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.02,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.01,       "cardinality":111101,       "extra_info": "info\\ninfo\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.68,          "cardinality":111101,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.38,             "cardinality":3036719,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "SEQ_SCAN",                "timing":0.95,                "cardinality":14835720,                "extra_info": "movie_info\\n[INFOSEPARATOR]\\ninfo\\nmovie_id\\ninfo_type_id",                "children": []                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=release dates",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.04,             "cardinality":16470,             "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.00,                "cardinality":71294,                "extra_info": "INNER\\ncompany_type_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.04,                   "cardinality":148132,                   "extra_info": "INNER\\ncompany_id=id\\n",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.01,                      "cardinality":2609129,                      "extra_info": "movie_companies\\n[INFOSEPARATOR]\\nmovie_id\\ncompany_id\\ncompany_type_id",                      "children": []                      },                   {                      "name": "SEQ_SCAN",                      "timing":0.01,                      "cardinality":9775,                      "extra_info": "company_name\\n[INFOSEPARATOR]\\ncountry_code\\nid\\n[INFOSEPARATOR]\\nFilters: \\ncountry_code=[de]",                      "children": []                      }                   ]                   },                {                   "name": "SEQ_SCAN",                   "timing":0.00,                   "cardinality":1,                   "extra_info": "company_type\\n[INFOSEPARATOR]\\nkind\\nid\\n[INFOSEPARATOR]\\nFilters: \\nkind=production companies",                   "children": []                   }                ]                },             {                "name": "HASH_JOIN",                "timing":0.02,     ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/2d.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/2d.sql.json.html
# <script>
# var graph_json = '{    "result": 2.315743,    "timings": {       "optimizer": 0.000967,       "optimizer > column_lifetime": 0.000008,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000000,       "optimizer > expression_rewriter": 0.000058,       "optimizer > filter_pullup": 0.000003,       "optimizer > filter_pushdown": 0.000227,       "optimizer > in_clause": 0.000002,       "optimizer > join_order": 0.000567,       "optimizer > regex_range": 0.000000,       "optimizer > reorder_filter": 0.000004,       "optimizer > statistics_propagation": 0.000061,       "optimizer > top_n": 0.000000,       "optimizer > unused_columns": 0.000012,       "physical_planner": 0.000074,       "physical_planner > column_binding": 0.000014,       "physical_planner > create_plan": 0.000048,       "physical_planner > resolve_types": 0.000005,       "planner": 0.000756,       "planner > binder": 0.000745    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":68316,       "extra_info": "title\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.01,          "cardinality":68316,          "extra_info": "INNER\\ncompany_id=id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.63,             "cardinality":148552,             "extra_info": "INNER\\nkeyword_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.86,                "cardinality":34863638,                "extra_info": "INNER\\nid=movie_id\\nmovie_id=movie_id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.27,                   "cardinality":4523930,                   "extra_info": "INNER\\nmovie_id=id\\n",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.08,                      "cardinality":4523930,                      "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                      "children": []                      },                   {                      "name": "SEQ_SCAN",                      "timing":0.04,                      "cardinality":2528312,                      "extra_info": "title\\n[INFOSEPARATOR]\\ntitle\\nid",                      "children": []                      }                   ]                   },                {                   "name": "SEQ_SCAN",                   "timing":0.07,                   "cardinality":2609129,                   "extra_info": "movie_companies\\n[INFOSEPARATOR]\\ncompany_id\\nmovie_id",                   "children": []                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.02,                "cardinality":1,                "extra_info": "keyword\\n[INFOSEPARATOR]\\nkeyword\\nid\\n[INFOSEPARATOR]\\nFilters: \\nkeyword=character-name-in-title",                "children": []                }             ]             },          {             "name": "SEQ_SCAN",             "timing":0.01,             "cardinality":84843,             "extra_info": "company_name\\n[INFOSEPARATOR]\\ncountry_code\\nid\\n[INFOSEPARATOR]\\nFilters: \\ncountry_code=[us]",             "children": []             }          ]          }       ]       }    ]    } }';
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/5c.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/5c.sql.json.html
# <script>
# ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/16a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/16a.sql.json.html
# <script>
# var graph_json = '{    "result": 4.979285,    "timings": {       "optimizer": 0.008898,       "optimizer > column_lifetime": 0.000020,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000048,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000280,       "optimizer > in_clause": 0.000001,       "optimizer > join_order": 0.008481,       "optimizer > regex_range": 0.000000,       "optimizer > reorder_filter": 0.000004,       "optimizer > statistics_propagation": 0.000028,       "optimizer > top_n": 0.000000,       "optimizer > unused_columns": 0.000013,       "physical_planner": 0.000068,       "physical_planner > column_binding": 0.000023,       "physical_planner > create_plan": 0.000027,       "physical_planner > resolve_types": 0.000007,       "planner": 0.000206,       "planner > binder": 0.000201    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":385,       "extra_info": "name\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.53,          "cardinality":385,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":3.91,             "cardinality":36417493,             "extra_info": "INNER\\nperson_id=id\\nperson_id=person_id\\n",             "children": [             {                "name": "SEQ_SCAN",                "timing":0.06,                "cardinality":36244344,                "extra_info": "cast_info\\n[INFOSEPARATOR]\\nperson_id\\nmovie_id",                "children": []                },             {                "name": "HASH_JOIN",                "timing":0.19,                "cardinality":901343,                "extra_info": "INNER\\nid=person_id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.00,                   "cardinality":4167491,                   "extra_info": "name\\n[INFOSEPARATOR]\\nid",                   "children": []                   },                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":901343,                   "extra_info": "aka_name\\n[INFOSEPARATOR]\\nname\\nperson_id",                   "children": []                   }                ]                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":25,             "extra_info": "INNER\\ncompany_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.00,                "cardinality":54,                "extra_info": "INNER\\nkeyword_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.05,                   "cardinality":4234,                   "extra_info": "INNER\\nid=movie_id\\nmovie_id=movie_id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.03,                      "cardinality":15655,                      "extra_info": "INNER\\nmovie_id=id\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":0.01,                         "cardinality":4523930,                         "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                         "children": []                         },                      {                         "name": "SEQ_SCAN",                         "timing":0.01,                         "car ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/9a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/9a.sql.json.html
# <script>
# var graph_json = '{    "result": 2.609519,    "timings": {       "optimizer": 0.010083,       "optimizer > column_lifetime": 0.000027,       "optimizer > common_aggregate": 0.000004,       "optimizer > common_subexpressions": 0.000003,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000379,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000401,       "optimizer > in_clause": 0.000019,       "optimizer > join_order": 0.009161,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000008,       "optimizer > statistics_propagation": 0.000043,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000017,       "physical_planner": 0.000096,       "physical_planner > column_binding": 0.000036,       "physical_planner > create_plan": 0.000035,       "physical_planner > resolve_types": 0.000011,       "planner": 0.000243,       "planner > binder": 0.000235    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":121,       "extra_info": "name\\nname\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.00,          "cardinality":121,          "extra_info": "INNER\\nperson_id=person_id\\nperson_id=id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.17,             "cardinality":28368,             "extra_info": "INNER\\nperson_role_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.08,                "cardinality":30619,                "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.08,                   "cardinality":276166,                   "extra_info": "INNER\\nrole_id=id\\n",                   "children": [                   {                      "name": "PROJECTION",                      "timing":0.02,                      "cardinality":867477,                      "extra_info": "#1\\n#2\\n#3\\n#4\\n",                      "children": [                      {                         "name": "FILTER",                         "timing":0.18,                         "cardinality":867477,                         "extra_info": "(note=(voice) OR note=(voice: Japanese version) OR note=(voice) (uncredited) OR note=(voice: English version))",                         "children": [                         {                            "name": "SEQ_SCAN",                            "timing":1.38,                            "cardinality":940580,                            "extra_info": "cast_info\\n[INFOSEPARATOR]\\nnote\\nmovie_id\\nrole_id\\nperson_id\\nperson_role_id\\n[INFOSEPARATOR]\\nFilters: \\nnote>=(voice)\\nnote<=(voice: Japanese version)",                            "children": []                            }                         ]                         }                      ]                      },                   {                      "name": "SEQ_SCAN",                      "timing":0.00,                      "cardinality":1,                      "extra_info": "role_type\\n[INFOSEPARATOR]\\nrole\\nid\\n[INFOSEPARATOR]\\nFilters: \\nrole=actress",                      "children": []                      }                   ]                   },                {                   "name": "HASH_JOIN",                   "timing":0.01,                   "cardinality":144120,                   "extra_info": "INNER\\ncompany_id=id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.06,                      "cardinality":166911,                      "extra_info": "INNER\\nmovie_id=id\\n",         ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/23a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/23a.sql.json.html
# <script>
# var graph_json = '{    "result": 1.046406,    "timings": {       "optimizer": 0.013884,       "optimizer > column_lifetime": 0.000095,       "optimizer > common_aggregate": 0.000030,       "optimizer > common_subexpressions": 0.000004,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000428,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000477,       "optimizer > in_clause": 0.000003,       "optimizer > join_order": 0.012705,       "optimizer > regex_range": 0.000002,       "optimizer > reorder_filter": 0.000009,       "optimizer > statistics_propagation": 0.000073,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000031,       "physical_planner": 0.000209,       "physical_planner > column_binding": 0.000088,       "physical_planner > create_plan": 0.000074,       "physical_planner > resolve_types": 0.000018,       "planner": 0.000336,       "planner > binder": 0.000328    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":618,       "extra_info": "kind\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.06,          "cardinality":618,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":1783,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "PROJECTION",                "timing":0.00,                "cardinality":1783,                "extra_info": "#2\\n#3\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.19,                   "cardinality":1783,                   "extra_info": "((~~(info, USA:% 199%) OR ~~(info, USA:% 200%)) AND contains(note, internet))",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.33,                      "cardinality":14835720,                      "extra_info": "movie_info\\n[INFOSEPARATOR]\\nnote\\ninfo\\nmovie_id\\ninfo_type_id",                      "children": []                      }                   ]                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=release dates",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.06,             "cardinality":760449,             "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.08,                "cardinality":4523930,                "extra_info": "INNER\\nkeyword_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":4523930,                   "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                   "children": []                   },                {                   "name": "SEQ_SCAN",                   "timing":0.00,                   "cardinality":134170,                   "extra_info": "keyword\\n[INFOSEPARATOR]\\nid",                   "children": []                   }                ]                },             {                "name": "HASH_JOIN",                "timing":0.03,                "cardinality":5763,                "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\n",       ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# 🧽🧽🧽🧽🧽🧽🧽🧽🧽🧽🧽🧽counter =  114

# %% [markdown]
# # Plotting

# %% [markdown]
# plotting the *.json under duckdb-rl-back-up-visualization/query-graph/profiling

# %% [markdown]
# ## JOB with DuckDB Optimizer

# %%
job_duckdb_dir = cwd + '/records/0426 profiling with DuckDB optimizer'

# %%
def read_json_from_dir(folder_dir, df):
    count_json = 0 #initialize amount of json files
    for file in os.listdir(folder_dir):
        if file.endswith(".json"):
            file_dir = folder_dir+'/'+file
            with open(file_dir, 'r') as f:
                count_json+=1
                data = f.read()
                data_df = pd.json_normalize(json.loads(data))
                data_df['job_query'] = file
                #print(type(data_df))
                df = pd.concat([df,data_df], sort=False)
    print(str(count_json) + " json files have been loaded!")

# %%
df = pd.DataFrame() #initialize datafram
read_json_from_dir(job_duckdb_dir, df)
# Out:
# 113 json files have been loaded!

# %%
# for file in os.listdir(job_duckdb_dir):
#     if file.endswith(".json"):
#         file_path = job_duckdb_dir+'/'+file
#         with open(file_path, 'r') as f:
#             count_json+=1
#             data = f.read()
#             data_df = pd.json_normalize(json.loads(data))
#             data_df['job_query'] = file
#             #print(type(data_df))
#             df = pd.concat([df,data_df], sort=False)

# %%
# drop useless columns, rename column names, move 'job_query' column to the first, sort by 'job_query'
df = df.drop(['tree.name', 'tree.timing', 'tree.cardinality', 'tree.extra_info', 'tree.children'], axis = 1)
df.columns = df.columns.str.replace('[>]','.', regex=True)
df.columns = df.columns.str.replace('[ ]','', regex=True)
df = df[ ['job_query'] + [ col for col in df.columns if col != 'job_query' ] ]
df.sort_values(by = 'job_query')
display(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-307542276062> in <module>
#       1 # drop useless columns, rename column names, move 'job_query' column to the first, sort by 'job_query'
# ----> 2 df = df.drop(['tree.name', 'tree.timing', 'tree.cardinality', 'tree.extra_info', 'tree.children'], axis = 1)
#       3 df.columns = df.columns.str.replace('[>]','.', regex=True)
#       4 df.columns = df.columns.str.replace('[ ]','', regex=True)
#       5 df = df[ ['job_query'] + [ col for col in df.columns if col != 'job_query' ] ]
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['tree.name' 'tree.timing' 'tree.cardinality' 'tree.extra_info'\n 'tree.children'] not found in axis"

# %%
df[['job_query','result']].plot(x='job_query')
plt.show()

# %% [markdown]
# ## JOB without any Optimizer

# %%
test_data = {
    'A':['A1', 'A2', 'A3', 'A4', 'A5'], 
    'B':['B1', 'B2', 'B3', 'B4', 'B5'], 
    'C':['C1', 'C2', 'C3', 'C4', 'C5'], 
    'D':['D1', 'D2', 'D3', 'D4', 'D5'], 
    'E':['E1', 'E2', 'E3', 'E4', 'E5'] }
test_df = pd.DataFrame(test_data)

# %%
display(test_df)
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %%
test_df.drop(['C','D'], axis =1)
# Out:
#     A   B   E
# 0  A1  B1  E1
# 1  A2  B2  E2
# 2  A3  B3  E3
# 3  A4  B4  E4
# 4  A5  B5  E5
