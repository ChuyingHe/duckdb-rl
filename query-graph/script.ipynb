# %%
import duckdb
import os 
#cursor = duckdb.connect()
#print(cursor.execute('SELECT 42').fetchall())

# %%
python scripts/generate_querygraph.py /path/to/file.json

# %%
import duckdb_query_graph

# %%
cwd = os.getcwd()
profiling_dir = cwd+"/profiling"
print(profiling_dir)
for json_filename in os.listdir(profiling_dir):
    html_filename = json_filename +'.html'
    json_dir = profiling_dir +"/"+ json_filename
    html_dir = profiling_dir +"/"+ html_filename
    print(json_dir, " --> ", html_dir)
    duckdb_query_graph.generate(json_dir, html_dir)
# Out:
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/17c.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/17c.sql.json.html
# <script>
# var graph_json = '{    "result": 1.975770,    "timings": {       "optimizer": 0.009041,       "optimizer > column_lifetime": 0.000017,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000003,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000143,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000190,       "optimizer > in_clause": 0.000002,       "optimizer > join_order": 0.008624,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000024,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000010,       "physical_planner": 0.000075,       "physical_planner > column_binding": 0.000019,       "physical_planner > create_plan": 0.000041,       "physical_planner > resolve_types": 0.000007,       "planner": 0.000195,       "planner > binder": 0.000189    },    "tree": {    "name": "PROJECTION",    "timing":0.00,    "cardinality":1,    "extra_info": "member_in_charnamed_movie\\na1\\n",    "children": [    {       "name": "SIMPLE_AGGREGATE",       "timing":0.00,       "cardinality":1,       "extra_info": "min(#0)",       "children": [       {          "name": "PROJECTION",          "timing":0.00,          "cardinality":1918,          "extra_info": "name\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":1918,             "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.14,                "cardinality":12500,                "extra_info": "INNER\\nperson_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.05,                   "cardinality":36244344,                   "extra_info": "cast_info\\n[INFOSEPARATOR]\\nperson_id\\nmovie_id",                   "children": []                   },                {                   "name": "FILTER",                   "timing":0.00,                   "cardinality":2664,                   "extra_info": "prefix(name, X)",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.06,                      "cardinality":2664,                      "extra_info": "name\\n[INFOSEPARATOR]\\nname\\nid\\n[INFOSEPARATOR]\\nFilters: \\nname>=X\\nname<Y",                      "children": []                      }                   ]                   }                ]                },             {                "name": "HASH_JOIN",                "timing":0.01,                "cardinality":148552,                "extra_info": "INNER\\ncompany_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.56,                   "cardinality":148552,                   "extra_info": "INNER\\nkeyword_id=id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.79,                      "cardinality":34863638,                      "extra_info": "INNER\\nid=movie_id\\nmovie_id=movie_id\\n",                      "children": [                      {                         "name": "HASH_JOIN",                         "timing":0.11,                         "cardinality":4523930,                         "extra_info": "INNER\\nmovie_id=id\\n",                         "children": [                         {                            "name": "SEQ_SCAN",                            "timing":0.01,                            "cardinality":4523930,                            "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                            "children": []                            },             ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/17b.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/17b.sql.json.html
# <script>
# var graph_json = '{    "result": 2.057586,    "timings": {       "optimizer": 0.008642,       "optimizer > column_lifetime": 0.000017,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000139,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000186,       "optimizer > in_clause": 0.000002,       "optimizer > join_order": 0.008225,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000028,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000012,       "physical_planner": 0.000064,       "physical_planner > column_binding": 0.000021,       "physical_planner > create_plan": 0.000027,       "physical_planner > resolve_types": 0.000006,       "planner": 0.000176,       "planner > binder": 0.000170    },    "tree": {    "name": "PROJECTION",    "timing":0.00,    "cardinality":1,    "extra_info": "member_in_charnamed_movie\\na1\\n",    "children": [    {       "name": "SIMPLE_AGGREGATE",       "timing":0.00,       "cardinality":1,       "extra_info": "min(#0)",       "children": [       {          "name": "PROJECTION",          "timing":0.00,          "cardinality":52306,          "extra_info": "name\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.05,             "cardinality":52306,             "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.18,                "cardinality":268710,                "extra_info": "INNER\\nperson_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.04,                   "cardinality":36244344,                   "extra_info": "cast_info\\n[INFOSEPARATOR]\\nperson_id\\nmovie_id",                   "children": []                   },                {                   "name": "FILTER",                   "timing":0.00,                   "cardinality":36174,                   "extra_info": "prefix(name, Z)",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.06,                      "cardinality":36174,                      "extra_info": "name\\n[INFOSEPARATOR]\\nname\\nid\\n[INFOSEPARATOR]\\nFilters: \\nname>=Z\\nname<[",                      "children": []                      }                   ]                   }                ]                },             {                "name": "HASH_JOIN",                "timing":0.01,                "cardinality":148552,                "extra_info": "INNER\\ncompany_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.56,                   "cardinality":148552,                   "extra_info": "INNER\\nkeyword_id=id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.78,                      "cardinality":34863638,                      "extra_info": "INNER\\nid=movie_id\\nmovie_id=movie_id\\n",                      "children": [                      {                         "name": "HASH_JOIN",                         "timing":0.11,                         "cardinality":4523930,                         "extra_info": "INNER\\nmovie_id=id\\n",                         "children": [                         {                            "name": "SEQ_SCAN",                            "timing":0.01,                            "cardinality":4523930,                            "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                            "children": []                            },        ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/6f.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/6f.sql.json.html
# <script>
# var graph_json = '{    "result": 3.226183,    "timings": {       "optimizer": 0.000928,       "optimizer > column_lifetime": 0.000020,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000023,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000124,       "optimizer > in_clause": 0.000041,       "optimizer > join_order": 0.000661,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000020,       "optimizer > top_n": 0.000000,       "optimizer > unused_columns": 0.000011,       "physical_planner": 0.000054,       "physical_planner > column_binding": 0.000016,       "physical_planner > create_plan": 0.000024,       "physical_planner > resolve_types": 0.000006,       "planner": 0.000146,       "planner > binder": 0.000142    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.02,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":785477,       "extra_info": "keyword\\nname\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":1.98,          "cardinality":785477,          "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.71,             "cardinality":36244344,             "extra_info": "INNER\\nperson_id=id\\n",             "children": [             {                "name": "SEQ_SCAN",                "timing":0.05,                "cardinality":36244344,                "extra_info": "cast_info\\n[INFOSEPARATOR]\\nmovie_id\\nperson_id",                "children": []                },             {                "name": "SEQ_SCAN",                "timing":0.04,                "cardinality":4167491,                "extra_info": "name\\n[INFOSEPARATOR]\\nname\\nid",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.03,             "cardinality":14165,             "extra_info": "INNER\\nkeyword_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.10,                "cardinality":1970380,                "extra_info": "INNER\\nmovie_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":4523930,                   "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nkeyword_id\\nmovie_id",                   "children": []                   },                {                   "name": "SEQ_SCAN",                   "timing":0.03,                   "cardinality":1381453,                   "extra_info": "title\\n[INFOSEPARATOR]\\ntitle\\nproduction_year\\nid\\n[INFOSEPARATOR]\\nFilters: \\nproduction_year>2000",                   "children": []                   }                ]                },             {                "name": "PROJECTION",                "timing":0.00,                "cardinality":8,                "extra_info": "#0\\n#1\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.00,                   "cardinality":8,                   "extra_info": "IN (...)",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.00,                      "cardinality":119352,                      "extra_info": "MARK\\nkeyword=#0\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":0.01,                         "cardinality":119352,                         "extra_info": "keyw ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/22c.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/22c.sql.json.html
# <script>
# var graph_json = '{    "result": 2.632063,    "timings": {       "optimizer": 0.011442,       "optimizer > column_lifetime": 0.000072,       "optimizer > common_aggregate": 0.000004,       "optimizer > common_subexpressions": 0.000004,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000181,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000434,       "optimizer > in_clause": 0.000111,       "optimizer > join_order": 0.010525,       "optimizer > regex_range": 0.000002,       "optimizer > reorder_filter": 0.000008,       "optimizer > statistics_propagation": 0.000049,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000031,       "physical_planner": 0.000135,       "physical_planner > column_binding": 0.000053,       "physical_planner > create_plan": 0.000050,       "physical_planner > resolve_types": 0.000013,       "planner": 0.000256,       "planner > binder": 0.000250    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":21489,       "extra_info": "name\\ninfo\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.11,          "cardinality":21489,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":614251,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "PROJECTION",                "timing":0.00,                "cardinality":716210,                "extra_info": "#1\\n#2\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.02,                   "cardinality":716210,                   "extra_info": "IN (...)",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.60,                      "cardinality":11827587,                      "extra_info": "MARK\\ninfo=#0\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":1.44,                         "cardinality":11827587,                         "extra_info": "movie_info\\n[INFOSEPARATOR]\\ninfo\\nmovie_id\\ninfo_type_id\\n[INFOSEPARATOR]\\nFilters: \\ninfo>=American\\ninfo<=USA",                         "children": []                         },                      {                         "name": "CHUNK_SCAN",                         "timing":0.00,                         "cardinality":10,                         "extra_info": "",                         "children": []                         }                      ]                      }                   ]                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=countries",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":23425,             "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.03,                "cardinality":37091,                "extra_info": "INNER\\nkeyword_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":4523930,                   "extra_info": "movie_keyword\\n[INFOSEPARA ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/22b.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/22b.sql.json.html
# <script>
# var graph_json = '{    "result": 2.121738,    "timings": {       "optimizer": 0.011270,       "optimizer > column_lifetime": 0.000073,       "optimizer > common_aggregate": 0.000005,       "optimizer > common_subexpressions": 0.000003,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000167,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000453,       "optimizer > in_clause": 0.000007,       "optimizer > join_order": 0.010446,       "optimizer > regex_range": 0.000002,       "optimizer > reorder_filter": 0.000009,       "optimizer > statistics_propagation": 0.000054,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000029,       "physical_planner": 0.000130,       "physical_planner > column_binding": 0.000051,       "physical_planner > create_plan": 0.000049,       "physical_planner > resolve_types": 0.000013,       "planner": 0.000280,       "planner > binder": 0.000273    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":31,       "extra_info": "name\\ninfo\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.01,          "cardinality":31,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.01,             "cardinality":588764,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "PROJECTION",                "timing":0.00,                "cardinality":669336,                "extra_info": "#1\\n#2\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.29,                   "cardinality":669336,                   "extra_info": "(info=Germany OR info=German OR info=USA OR info=American)",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":1.43,                      "cardinality":11827587,                      "extra_info": "movie_info\\n[INFOSEPARATOR]\\ninfo\\nmovie_id\\ninfo_type_id\\n[INFOSEPARATOR]\\nFilters: \\ninfo>=American\\ninfo<=USA",                      "children": []                      }                   ]                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=countries",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":50,             "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.03,                "cardinality":37091,                "extra_info": "INNER\\nkeyword_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":4523930,                   "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                   "children": []                   },                {                   "name": "PROJECTION",                   "timing":0.00,                   "cardinality":3,                   "extra_info": "#1\\n",                   "children": [                   {                      "name": "FILTER",                      "timing":0.00,                      "cardinality":3,                      "extra_info": "(keyword=murder OR keyword=murder-in-title OR keyword=blood OR key ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/8b.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/8b.sql.json.html
# <script>
# var graph_json = '{    "result": 1.874948,    "timings": {       "optimizer": 0.008876,       "optimizer > column_lifetime": 0.000021,       "optimizer > common_aggregate": 0.000004,       "optimizer > common_subexpressions": 0.000003,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000609,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000294,       "optimizer > in_clause": 0.000002,       "optimizer > join_order": 0.007860,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000008,       "optimizer > statistics_propagation": 0.000035,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000018,       "physical_planner": 0.000097,       "physical_planner > column_binding": 0.000029,       "physical_planner > create_plan": 0.000045,       "physical_planner > resolve_types": 0.000009,       "planner": 0.000242,       "planner > binder": 0.000235    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":6,       "extra_info": "name\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.03,          "cardinality":6,          "extra_info": "INNER\\nid=person_id\\nperson_id=person_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":4,             "extra_info": "INNER\\nmovie_id=id\\nmovie_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.00,                "cardinality":16,                "extra_info": "INNER\\nrole_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.00,                   "cardinality":42,                   "extra_info": "INNER\\nmovie_id=movie_id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.02,                      "cardinality":938,                      "extra_info": "INNER\\nperson_id=id\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":1.54,                         "cardinality":93095,                         "extra_info": "cast_info\\n[INFOSEPARATOR]\\nnote\\nperson_id\\nmovie_id\\nrole_id\\n[INFOSEPARATOR]\\nFilters: \\nnote=(voice: English version)",                         "children": []                         },                      {                         "name": "PROJECTION",                         "timing":0.00,                         "cardinality":20911,                         "extra_info": "#1\\n",                         "children": [                         {                            "name": "FILTER",                            "timing":0.07,                            "cardinality":20911,                            "extra_info": "(!~~(name, %Yu%) AND contains(name, Yo))",                            "children": [                            {                               "name": "SEQ_SCAN",                               "timing":0.03,                               "cardinality":4167491,                               "extra_info": "name\\n[INFOSEPARATOR]\\nname\\nid",                               "children": []                               }                            ]                            }                         ]                         }                      ]                      },                   {                      "name": "HASH_JOIN",                      "timing":0.01,                      "cardinality":8495,                      "extra_info": "INNER\\ncompany_id=id\\n",                      "children": [                      {                         "name": "PROJECTION" ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/8c.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/8c.sql.json.html
# <script>
# var graph_json = '{    "result": 7.193905,    "timings": {       "optimizer": 0.008678,       "optimizer > column_lifetime": 0.000013,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000032,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000214,       "optimizer > in_clause": 0.000001,       "optimizer > join_order": 0.008353,       "optimizer > regex_range": 0.000000,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000024,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000012,       "physical_planner": 0.000065,       "physical_planner > column_binding": 0.000023,       "physical_planner > create_plan": 0.000025,       "physical_planner > resolve_types": 0.000007,       "planner": 0.000179,       "planner > binder": 0.000173    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.04,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)",    "children": [    {       "name": "PROJECTION",       "timing":0.02,       "cardinality":2487611,       "extra_info": "name\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":1.03,          "cardinality":2487611,          "extra_info": "INNER\\nid=person_id\\nperson_id=person_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":1.34,             "cardinality":1970658,             "extra_info": "INNER\\nmovie_id=id\\nmovie_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.44,                "cardinality":1970658,                "extra_info": "INNER\\nrole_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":3.19,                   "cardinality":32289229,                   "extra_info": "INNER\\nmovie_id=movie_id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.58,                      "cardinality":36244344,                      "extra_info": "INNER\\nperson_id=id\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":0.09,                         "cardinality":36244344,                         "extra_info": "cast_info\\n[INFOSEPARATOR]\\nperson_id\\nmovie_id\\nrole_id",                         "children": []                         },                      {                         "name": "SEQ_SCAN",                         "timing":0.00,                         "cardinality":4167491,                         "extra_info": "name\\n[INFOSEPARATOR]\\nid",                         "children": []                         }                      ]                      },                   {                      "name": "HASH_JOIN",                      "timing":0.04,                      "cardinality":1153798,                      "extra_info": "INNER\\ncompany_id=id\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":0.00,                         "cardinality":2609129,                         "extra_info": "movie_companies\\n[INFOSEPARATOR]\\nmovie_id\\ncompany_id",                         "children": []                         },                      {                         "name": "SEQ_SCAN",                         "timing":0.01,                         "cardinality":84843,                         "extra_info": "company_name\\n[INFOSEPARATOR]\\ncountry_code\\nid\\n[INFOSEPARATOR]\\nFilters: \\ncountry_code=[us]",                         "children": []                         }                      ]                      }                   ]                   },                {  ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/1a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/1a.sql.json.html
# <script>
# var graph_json = '{    "result": 0.464572,    "timings": {       "optimizer": 0.000939,       "optimizer > column_lifetime": 0.000012,       "optimizer > common_aggregate": 0.000003,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000000,       "optimizer > expression_rewriter": 0.000247,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000132,       "optimizer > in_clause": 0.000002,       "optimizer > join_order": 0.000489,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000006,       "optimizer > statistics_propagation": 0.000021,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000010,       "physical_planner": 0.000047,       "physical_planner > column_binding": 0.000016,       "physical_planner > create_plan": 0.000018,       "physical_planner > resolve_types": 0.000005,       "planner": 0.000142,       "planner > binder": 0.000138    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":142,       "extra_info": "note\\ntitle\\nproduction_year\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.00,          "cardinality":142,          "extra_info": "INNER\\ncompany_type_id=id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":147,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.15,                "cardinality":62658,                "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.10,                   "cardinality":28889,                   "extra_info": "(!~~(note, %(as Metro-Goldwyn-Mayer Pictures)%) AND (contains(note, (co-production)) OR contains(note, (presents))))",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.02,                      "cardinality":2609129,                      "extra_info": "movie_companies\\n[INFOSEPARATOR]\\nnote\\ncompany_type_id\\nmovie_id",                      "children": []                      }                   ]                   },                {                   "name": "HASH_JOIN",                   "timing":0.08,                   "cardinality":1380035,                   "extra_info": "INNER\\nid=movie_id\\n",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.04,                      "cardinality":2528312,                      "extra_info": "title\\n[INFOSEPARATOR]\\ntitle\\nproduction_year\\nid",                      "children": []                      },                   {                      "name": "SEQ_SCAN",                      "timing":0.00,                      "cardinality":1380035,                      "extra_info": "movie_info_idx\\n[INFOSEPARATOR]\\nmovie_id\\ninfo_type_id",                      "children": []                      }                   ]                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=top 250 rank",                "children": []                }             ]             },          {             "name": "SEQ_SCAN",             "timing":0.00,             "cardinality":1,             "extra_info": "company_type\\n[INFOSEPARATOR]\\nkind\\nid\\n[INFOSEPARATOR]\\nFilters: \\nkind=production companies",             "children": []             }          ]  ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/13a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/13a.sql.json.html
# <script>
# var graph_json = '{    "result": 0.844555,    "timings": {       "optimizer": 0.010537,       "optimizer > column_lifetime": 0.000039,       "optimizer > common_aggregate": 0.000004,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000057,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.001207,       "optimizer > in_clause": 0.000003,       "optimizer > join_order": 0.009139,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000036,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000021,       "physical_planner": 0.000102,       "physical_planner > column_binding": 0.000036,       "physical_planner > create_plan": 0.000036,       "physical_planner > resolve_types": 0.000012,       "planner": 0.000219,       "planner > binder": 0.000212    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":111101,       "extra_info": "info\\ninfo\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.06,          "cardinality":111101,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.16,             "cardinality":3036719,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "SEQ_SCAN",                "timing":0.27,                "cardinality":14835720,                "extra_info": "movie_info\\n[INFOSEPARATOR]\\ninfo\\nmovie_id\\ninfo_type_id",                "children": []                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=release dates",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.04,             "cardinality":16470,             "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.00,                "cardinality":71294,                "extra_info": "INNER\\ncompany_type_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.04,                   "cardinality":148132,                   "extra_info": "INNER\\ncompany_id=id\\n",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.01,                      "cardinality":2609129,                      "extra_info": "movie_companies\\n[INFOSEPARATOR]\\nmovie_id\\ncompany_id\\ncompany_type_id",                      "children": []                      },                   {                      "name": "SEQ_SCAN",                      "timing":0.01,                      "cardinality":9775,                      "extra_info": "company_name\\n[INFOSEPARATOR]\\ncountry_code\\nid\\n[INFOSEPARATOR]\\nFilters: \\ncountry_code=[de]",                      "children": []                      }                   ]                   },                {                   "name": "SEQ_SCAN",                   "timing":0.00,                   "cardinality":1,                   "extra_info": "company_type\\n[INFOSEPARATOR]\\nkind\\nid\\n[INFOSEPARATOR]\\nFilters: \\nkind=production companies",                   "children": []                   }                ]                },             {                "name": "HASH_JOIN",                "timing":0.01,     ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/2d.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/2d.sql.json.html
# <script>
# var graph_json = '{    "result": 1.887113,    "timings": {       "optimizer": 0.000750,       "optimizer > column_lifetime": 0.000008,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000001,       "optimizer > deliminator": 0.000000,       "optimizer > expression_rewriter": 0.000031,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000140,       "optimizer > in_clause": 0.000001,       "optimizer > join_order": 0.000517,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000004,       "optimizer > statistics_propagation": 0.000018,       "optimizer > top_n": 0.000000,       "optimizer > unused_columns": 0.000009,       "physical_planner": 0.000046,       "physical_planner > column_binding": 0.000014,       "physical_planner > create_plan": 0.000019,       "physical_planner > resolve_types": 0.000005,       "planner": 0.000134,       "planner > binder": 0.000129    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":68316,       "extra_info": "title\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.01,          "cardinality":68316,          "extra_info": "INNER\\ncompany_id=id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.58,             "cardinality":148552,             "extra_info": "INNER\\nkeyword_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.81,                "cardinality":34863638,                "extra_info": "INNER\\nid=movie_id\\nmovie_id=movie_id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.21,                   "cardinality":4523930,                   "extra_info": "INNER\\nmovie_id=id\\n",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.01,                      "cardinality":4523930,                      "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                      "children": []                      },                   {                      "name": "SEQ_SCAN",                      "timing":0.03,                      "cardinality":2528312,                      "extra_info": "title\\n[INFOSEPARATOR]\\ntitle\\nid",                      "children": []                      }                   ]                   },                {                   "name": "SEQ_SCAN",                   "timing":0.00,                   "cardinality":2609129,                   "extra_info": "movie_companies\\n[INFOSEPARATOR]\\ncompany_id\\nmovie_id",                   "children": []                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.02,                "cardinality":1,                "extra_info": "keyword\\n[INFOSEPARATOR]\\nkeyword\\nid\\n[INFOSEPARATOR]\\nFilters: \\nkeyword=character-name-in-title",                "children": []                }             ]             },          {             "name": "SEQ_SCAN",             "timing":0.01,             "cardinality":84843,             "extra_info": "company_name\\n[INFOSEPARATOR]\\ncountry_code\\nid\\n[INFOSEPARATOR]\\nFilters: \\ncountry_code=[us]",             "children": []             }          ]          }       ]       }    ]    } }';
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/5c.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/5c.sql.json.html
# <script>
# ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/16a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/16a.sql.json.html
# <script>
# var graph_json = '{    "result": 5.044545,    "timings": {       "optimizer": 0.010376,       "optimizer > column_lifetime": 0.000026,       "optimizer > common_aggregate": 0.000002,       "optimizer > common_subexpressions": 0.000002,       "optimizer > deliminator": 0.000000,       "optimizer > expression_rewriter": 0.000052,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000305,       "optimizer > in_clause": 0.000001,       "optimizer > join_order": 0.009914,       "optimizer > regex_range": 0.000001,       "optimizer > reorder_filter": 0.000005,       "optimizer > statistics_propagation": 0.000032,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000016,       "physical_planner": 0.000079,       "physical_planner > column_binding": 0.000028,       "physical_planner > create_plan": 0.000030,       "physical_planner > resolve_types": 0.000008,       "planner": 0.000197,       "planner > binder": 0.000191    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":385,       "extra_info": "name\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.53,          "cardinality":385,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":3.97,             "cardinality":36417493,             "extra_info": "INNER\\nperson_id=id\\nperson_id=person_id\\n",             "children": [             {                "name": "SEQ_SCAN",                "timing":0.06,                "cardinality":36244344,                "extra_info": "cast_info\\n[INFOSEPARATOR]\\nperson_id\\nmovie_id",                "children": []                },             {                "name": "HASH_JOIN",                "timing":0.19,                "cardinality":901343,                "extra_info": "INNER\\nid=person_id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.00,                   "cardinality":4167491,                   "extra_info": "name\\n[INFOSEPARATOR]\\nid",                   "children": []                   },                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":901343,                   "extra_info": "aka_name\\n[INFOSEPARATOR]\\nname\\nperson_id",                   "children": []                   }                ]                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":25,             "extra_info": "INNER\\ncompany_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.00,                "cardinality":54,                "extra_info": "INNER\\nkeyword_id=id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.05,                   "cardinality":4234,                   "extra_info": "INNER\\nid=movie_id\\nmovie_id=movie_id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.03,                      "cardinality":15655,                      "extra_info": "INNER\\nmovie_id=id\\n",                      "children": [                      {                         "name": "SEQ_SCAN",                         "timing":0.01,                         "cardinality":4523930,                         "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                         "children": []                         },                      {                         "name": "SEQ_SCAN",                         "timing":0.01,                         "car ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/9a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/9a.sql.json.html
# <script>
# var graph_json = '{    "result": 2.050854,    "timings": {       "optimizer": 0.010552,       "optimizer > column_lifetime": 0.000033,       "optimizer > common_aggregate": 0.000003,       "optimizer > common_subexpressions": 0.000003,       "optimizer > deliminator": 0.000000,       "optimizer > expression_rewriter": 0.000384,       "optimizer > filter_pullup": 0.000001,       "optimizer > filter_pushdown": 0.000345,       "optimizer > in_clause": 0.000004,       "optimizer > join_order": 0.009698,       "optimizer > regex_range": 0.000002,       "optimizer > reorder_filter": 0.000007,       "optimizer > statistics_propagation": 0.000037,       "optimizer > top_n": 0.000000,       "optimizer > unused_columns": 0.000017,       "physical_planner": 0.000090,       "physical_planner > column_binding": 0.000033,       "physical_planner > create_plan": 0.000034,       "physical_planner > resolve_types": 0.000010,       "planner": 0.000238,       "planner > binder": 0.000231    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)\\nmin(#2)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":121,       "extra_info": "name\\nname\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.00,          "cardinality":121,          "extra_info": "INNER\\nperson_id=person_id\\nperson_id=id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.14,             "cardinality":28368,             "extra_info": "INNER\\nperson_role_id=id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.08,                "cardinality":30619,                "extra_info": "INNER\\nmovie_id=id\\nmovie_id=movie_id\\n",                "children": [                {                   "name": "HASH_JOIN",                   "timing":0.07,                   "cardinality":276166,                   "extra_info": "INNER\\nrole_id=id\\n",                   "children": [                   {                      "name": "PROJECTION",                      "timing":0.02,                      "cardinality":867477,                      "extra_info": "#1\\n#2\\n#3\\n#4\\n",                      "children": [                      {                         "name": "FILTER",                         "timing":0.16,                         "cardinality":867477,                         "extra_info": "(note=(voice) OR note=(voice: Japanese version) OR note=(voice) (uncredited) OR note=(voice: English version))",                         "children": [                         {                            "name": "SEQ_SCAN",                            "timing":0.96,                            "cardinality":940580,                            "extra_info": "cast_info\\n[INFOSEPARATOR]\\nnote\\nmovie_id\\nrole_id\\nperson_id\\nperson_role_id\\n[INFOSEPARATOR]\\nFilters: \\nnote>=(voice)\\nnote<=(voice: Japanese version)",                            "children": []                            }                         ]                         }                      ]                      },                   {                      "name": "SEQ_SCAN",                      "timing":0.00,                      "cardinality":1,                      "extra_info": "role_type\\n[INFOSEPARATOR]\\nrole\\nid\\n[INFOSEPARATOR]\\nFilters: \\nrole=actress",                      "children": []                      }                   ]                   },                {                   "name": "HASH_JOIN",                   "timing":0.01,                   "cardinality":144120,                   "extra_info": "INNER\\ncompany_id=id\\n",                   "children": [                   {                      "name": "HASH_JOIN",                      "timing":0.06,                      "cardinality":166911,                      "extra_info": "INNER\\nmovie_id=id\\n",         ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
#
# /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/23a.sql.json  -->  /Users/chuyinghe/CLionProjects/duckdb-rl/query-graph/profiling/23a.sql.json.html
# <script>
# var graph_json = '{    "result": 0.883050,    "timings": {       "optimizer": 0.009991,       "optimizer > column_lifetime": 0.000058,       "optimizer > common_aggregate": 0.000004,       "optimizer > common_subexpressions": 0.000004,       "optimizer > deliminator": 0.000001,       "optimizer > expression_rewriter": 0.000346,       "optimizer > filter_pullup": 0.000002,       "optimizer > filter_pushdown": 0.000422,       "optimizer > in_clause": 0.000003,       "optimizer > join_order": 0.009040,       "optimizer > regex_range": 0.000002,       "optimizer > reorder_filter": 0.000008,       "optimizer > statistics_propagation": 0.000062,       "optimizer > top_n": 0.000001,       "optimizer > unused_columns": 0.000022,       "physical_planner": 0.000136,       "physical_planner > column_binding": 0.000043,       "physical_planner > create_plan": 0.000066,       "physical_planner > resolve_types": 0.000012,       "planner": 0.000297,       "planner > binder": 0.000290    },    "tree": {    "name": "SIMPLE_AGGREGATE",    "timing":0.00,    "cardinality":1,    "extra_info": "min(#0)\\nmin(#1)",    "children": [    {       "name": "PROJECTION",       "timing":0.00,       "cardinality":618,       "extra_info": "kind\\ntitle\\n",       "children": [       {          "name": "HASH_JOIN",          "timing":0.06,          "cardinality":618,          "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\nmovie_id=movie_id\\n",          "children": [          {             "name": "HASH_JOIN",             "timing":0.00,             "cardinality":1783,             "extra_info": "INNER\\ninfo_type_id=id\\n",             "children": [             {                "name": "PROJECTION",                "timing":0.00,                "cardinality":1783,                "extra_info": "#2\\n#3\\n",                "children": [                {                   "name": "FILTER",                   "timing":0.18,                   "cardinality":1783,                   "extra_info": "((~~(info, USA:% 199%) OR ~~(info, USA:% 200%)) AND contains(note, internet))",                   "children": [                   {                      "name": "SEQ_SCAN",                      "timing":0.31,                      "cardinality":14835720,                      "extra_info": "movie_info\\n[INFOSEPARATOR]\\nnote\\ninfo\\nmovie_id\\ninfo_type_id",                      "children": []                      }                   ]                   }                ]                },             {                "name": "SEQ_SCAN",                "timing":0.00,                "cardinality":1,                "extra_info": "info_type\\n[INFOSEPARATOR]\\ninfo\\nid\\n[INFOSEPARATOR]\\nFilters: \\ninfo=release dates",                "children": []                }             ]             },          {             "name": "HASH_JOIN",             "timing":0.06,             "cardinality":760449,             "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\nmovie_id=movie_id\\n",             "children": [             {                "name": "HASH_JOIN",                "timing":0.08,                "cardinality":4523930,                "extra_info": "INNER\\nkeyword_id=id\\n",                "children": [                {                   "name": "SEQ_SCAN",                   "timing":0.01,                   "cardinality":4523930,                   "extra_info": "movie_keyword\\n[INFOSEPARATOR]\\nmovie_id\\nkeyword_id",                   "children": []                   },                {                   "name": "SEQ_SCAN",                   "timing":0.00,                   "cardinality":134170,                   "extra_info": "keyword\\n[INFOSEPARATOR]\\nid",                   "children": []                   }                ]                },             {                "name": "HASH_JOIN",                "timing":0.02,                "cardinality":5763,                "extra_info": "INNER\\nmovie_id=movie_id\\nmovie_id=id\\n",       ...
# var result = parse_profiling_output(graph_json);
# var meta_info = result[0];
# var graph_data = result[1];
# document.getElementById('meta-info').innerHTML = meta_info;
# if (graph_data !== null && graph_data !== undefined) {
# 	create_graph(graph_data, '#query-profile', '.chart');
# }
# </script>
